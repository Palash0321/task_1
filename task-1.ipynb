# %%
import pandas as pd

# %%
df = pd.read_csv("C:/Jaipuria trimester IV/SIP (EL)/netflix_titles.csv/netflix_titles.csv")

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df.describe()
# Out:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %% [markdown]
# ## Rows = 8807
# ## Columns = 12

# %%
df.shape
# Out:
# (8807, 12)

# %% [markdown]
# ## Missing values

# %%
df.isnull().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# dtype: int64

# %% [markdown]
# ### Handling missing values

# %%
df['director'].fillna('Unknown',inplace=True)

# %%
df['cast'].fillna('Unknown',inplace=True)

# %%
df['country'].fillna('Unknown',inplace=True)

# %%
df['date_added'].fillna('Unknown',inplace=True)

# %%
df['rating'].fillna('Unknown',inplace=True)
df['duration'].fillna('Unknown',inplace=True)

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water          Unknown
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans          Unknown
# 4         s5  TV Show           Kota Factory          Unknown
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb          Unknown
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                               Unknown  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
print("----No missing Values Found----")
# Out:
# ----No missing Values Found----

# %% [markdown]
# ### Remove Duplicate Rows:

# %%
print("\n--- Removing Duplicate Rows ---")
# This will remove duplicates based on 'show_id' if any exist.
df.drop_duplicates(subset=['show_id'], inplace=True)
print("Duplicate rows based on 'show_id' removed (if any were present).")
print("Number of rows after duplicate removal:", len(df))
# Out:
# --- Removing Duplicate Rows ---
# Duplicate rows based on 'show_id' removed (if any were present).
# Number of rows after duplicate removal: 8807

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water          Unknown
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans          Unknown
# 4         s5  TV Show           Kota Factory          Unknown
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb          Unknown
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                               Unknown  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %% [markdown]
# ### Standardize Text Values:

# %%
print("\n--- Standardizing Text Values ---")
# Standardize 'type' to lowercase
df['type'] = df['type'].str.lower()
print(f"Unique 'type' values after standardization: {df['type'].unique()}")
# Out:
# --- Standardizing Text Values ---
# Unique 'type' values after standardization: ['movie' 'tv show']

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  tv show          Blood & Water          Unknown
# 2         s3  tv show              Ganglands  Julien Leclercq
# 3         s4  tv show  Jailbirds New Orleans          Unknown
# 4         s5  tv show           Kota Factory          Unknown
# ...      ...      ...                    ...              ...
# 8802   s8803    movie                 Zodiac    David Fincher
# 8803   s8804  tv show            Zombie Dumb          Unknown
# 8804   s8805    movie             Zombieland  Ruben Fleischer
# 8805   s8806    movie                   Zoom     Peter Hewitt
# 8806   s8807    movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                               Unknown  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %% [markdown]
# ### Standardize 'listed_in' (genres) - strip whitespace, split, strip again, then join

# %%
df['listed_in'] = df['listed_in'].apply(lambda x: ', '.join([s.strip().title() for s in x.split(',')]))
print(f"Example 'listed_in' values after standardization (first 5 unique): {df['listed_in'].unique()[:5]}")
# Out:
# Example 'listed_in' values after standardization (first 5 unique): ['Documentaries' 'International Tv Shows, Tv Dramas, Tv Mysteries'
#  'Crime Tv Shows, International Tv Shows, Tv Action & Adventure'
#  'Docuseries, Reality Tv'
#  'International Tv Shows, Romantic Tv Shows, Tv Comedies']

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  tv show          Blood & Water          Unknown
# 2         s3  tv show              Ganglands  Julien Leclercq
# 3         s4  tv show  Jailbirds New Orleans          Unknown
# 4         s5  tv show           Kota Factory          Unknown
# ...      ...      ...                    ...              ...
# 8802   s8803    movie                 Zodiac    David Fincher
# 8803   s8804  tv show            Zombie Dumb          Unknown
# 8804   s8805    movie             Zombieland  Ruben Fleischer
# 8805   s8806    movie                   Zoom     Peter Hewitt
# 8806   s8807    movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                               Unknown  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %% [markdown]
# ### Standardize 'director', 'cast', 'country', 'rating' to Title Case and strip whitespace

# %%
text_cols_to_standardize = ['director', 'cast', 'country', 'rating']
for col in text_cols_to_standardize:
 df[col] = df[col].str.strip().str.title()
 print(f"Column '{col}' standardized to Title Case and stripped whitespace.")
# Out:
# Column 'director' standardized to Title Case and stripped whitespace.
# Column 'cast' standardized to Title Case and stripped whitespace.
# Column 'country' standardized to Title Case and stripped whitespace.
# Column 'rating' standardized to Title Case and stripped whitespace.

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  tv show          Blood & Water          Unknown
# 2         s3  tv show              Ganglands  Julien Leclercq
# 3         s4  tv show  Jailbirds New Orleans          Unknown
# 4         s5  tv show           Kota Factory          Unknown
# ...      ...      ...                    ...              ...
# 8802   s8803    movie                 Zodiac    David Fincher
# 8803   s8804  tv show            Zombie Dumb          Unknown
# 8804   s8805    movie             Zombieland  Ruben Fleischer
# 8805   s8806    movie                   Zoom     Peter Hewitt
# 8806   s8807    movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                               Unknown  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
print("\n--- Final DataFrame Info After All Cleaning Steps ---")
print(df.info())

# Ensure 'release_year' is integer type
df['release_year'] = df['release_year'].astype(int)
print("\n'release_year' column ensured to be integer type.")
# Out:
# --- Final DataFrame Info After All Cleaning Steps ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      8807 non-null   object
#  4   cast          8807 non-null   object
#  5   country       8807 non-null   object
#  6   date_added    8807 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8807 non-null   object
#  9   duration      8807 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB
# None
#
# 'release_year' column ensured to be integer type.

# %% [markdown]
#  ### --- Verification of 'director' and 'cast' columns ---

# %%
print("\n--- Verification of 'director' and 'cast' columns ---")
print("\nTop 10 value counts for 'director' (should show names and 'Unknown'):")
print(df['director'].value_counts().head(10).to_markdown(numalign="left", stralign="left"))
# Out:
# --- Verification of 'director' and 'cast' columns ---
#
# Top 10 value counts for 'director' (should show names and 'Unknown'):
# | director               | count   |
# |:-----------------------|:--------|
# | Unknown                | 2634    |
# | Rajiv Chilaka          | 19      |
# | Raúl Campos, Jan Suter | 18      |
# | Suhas Kadav            | 16      |
# | Marcus Raboy           | 16      |
# | Jay Karas              | 14      |
# | Cathy Garcia-Molina    | 13      |
# | Jay Chapman            | 12      |
# | Martin Scorsese        | 12      |
# | Youssef Chahine        | 12      |

# %%
print("\nTop 10 value counts for 'cast' (should show names and 'Unknown'):")
print(df['cast'].value_counts().head(10).to_markdown(numalign="left", stralign="left"))
# Out:
# Top 10 value counts for 'cast' (should show names and 'Unknown'):
# | cast                                                                                                                   | count   |
# |:-----------------------------------------------------------------------------------------------------------------------|:--------|
# | Unknown                                                                                                                | 825     |
# | David Attenborough                                                                                                     | 19      |
# | Vatsal Dubey, Julie Tejwani, Rupa Bhimani, Jigna Bhardwaj, Rajesh Kava, Mousam, Swapnil                                | 14      |
# | Samuel West                                                                                                            | 10      |
# ...

# %%
  # Display the first few rows of the cleaned DataFrame
print("\n--- First 5 rows of Fully Cleaned Netflix DataFrame ---")
print(df.head().to_markdown(index=False, numalign="left", stralign="left"))
# Out:
# --- First 5 rows of Fully Cleaned Netflix DataFrame ---
# | show_id   | type    | title                 | director        | cast                                                                                                                                                                                                                                                                                                            | country       | date_added         | release_year   | rating   | duration   | listed_in                                                     | description                                                                                                                                              |
# ...
